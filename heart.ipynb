# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Univariate Analysis

# %% [markdown]
# #### Age

# %% [markdown]
# ##### Conclusion
# - The Distribution of the Age column is almost normal.

# %%
df['age'].isnull().sum()/len(df['age'])
# Out:
# 0.0

# %%
df['age'].describe()
# Out:
# count    302.00000
# mean      54.42053
# std        9.04797
# min       29.00000
# 25%       48.00000
# 50%       55.50000
# 75%       61.00000
# max       77.00000
# Name: age, dtype: float64

# %%
age = df['age']
age.plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
age.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
age.plot(kind='line')
# Out:
# <Axes: >

# %%
age.skew()
# Out:
# -0.2037432795959691

# %%
sns.boxplot(age)
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# #### Sex

# %% [markdown]
# ##### Conclusion
# - there are more than 68% male patients in comparision of females.(total)

# %%
df['sex'].value_counts().reset_index()
# Out:
#    sex  count
# 0    1    206
# 1    0     96

# %%
df['sex'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='sex'>

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### CP - chest pain

# %% [markdown]
# ##### Conclusion
# - chest pain level 2 patients are more than expected and level zero means no pain patients are almost 47%.

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
df['cp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cp'>

# %%
df['cp'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### Blood Pressure

# %% [markdown]
# #### Conclusion
# - Distribution is normal.
# - there are some outliers present in the Bps column.

# %%
df['trtbps'].isnull().sum()/len(df['trtbps'])
# Out:
# 0.0

# %%
df['trtbps'].describe().reset_index()
# Out:
#    index      trtbps
# 0  count  302.000000
# 1   mean  131.602649
# 2    std   17.563394
# 3    min   94.000000
# 4    25%  120.000000
# 5    50%  130.000000
# 6    75%  140.000000
# 7    max  200.000000

# %%
bps = df['trtbps']

# %%
bps.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
bps.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
bps.var()  #variance
# Out:
# 308.4728168797166

# %%
bps.skew()
# Out:
# 0.7165414326647318

# %%
sns.boxplot(bps)
# Out:
# <Axes: ylabel='trtbps'>

# %% [markdown]
# #### cholesterol - chol

# %% [markdown]
# ##### Conclusion
# - Distribution is normal but there are some outliers present.

# %%
chol = df['chol']

# %%
chol.describe()
# Out:
# count    302.000000
# mean     246.500000
# std       51.753489
# min      126.000000
# 25%      211.000000
# 50%      240.500000
# 75%      274.750000
# max      564.000000
# Name: chol, dtype: float64

# %%
chol.skew()
# Out:
# 1.147332413980798

# %%
chol.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
chol.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.boxplot(chol)
# Out:
# <Axes: ylabel='chol'>

# %%
chol.plot(kind='line')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %% [markdown]
# #### Fasting Glucose level - fbs
# - The expected values for normal fasting blood glucose concentration are between 70 mg/dL (3.9 mmol/L) and 100 mg/dL (5.6 mmol/L). When fasting blood glucose is between 100 to 125 mg/dL (5.6 to 6.9 mmol/L) changes in lifestyle and monitoring glycemia are recommended. If fasting blood glucose is 126 mg/dL (7 mmol/L) or higher on two separate tests, diabetes is diagnosed.

# %% [markdown]
# ##### Conclusion

# %%
fbs = df['fbs']

# %%
fbs.value_counts()
# Out:
# fbs
# 0    257
# 1     45
# Name: count, dtype: int64

# %%
fbs.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fbs'>

# %%
fbs.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### thalach - max heart rate

# %% [markdown]
# ##### conclusion
# - mean heart rate is around 150.
# - there is one outlier which is 71.

# %%
df['thalachh'].describe()
# Out:
# count    302.000000
# mean     149.569536
# std       22.903527
# min       71.000000
# 25%      133.250000
# 50%      152.500000
# 75%      166.000000
# max      202.000000
# Name: thalachh, dtype: float64

# %%
df['thalachh'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['thalachh'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['thalachh'].var()
# Out:
# 524.5715605817254

# %%
sns.boxplot(df['thalachh'])
# Out:
# <Axes: ylabel='thalachh'>

# %%
df[df['thalachh']<80]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 272   67    1   0     120   237    0        1        71     0      1.0    1
#
#      caa  thall  output
# 272    0      2       0

# %%
df['thalachh'].skew()
# Out:
# -0.5326712468229611

# %% [markdown]
# #### sex - output

# %% [markdown]
# ##### conclusion
# - 56% male patients are diagnosed with the heart disease.(from the total diagnosed patients)
# - 44% male patients are diagnosed (from the total male patients)
# - 43% female patients are diagnosed with the heart disease.(from the total diagnosed patients)
# - 75% female patients are diagnosed (from the total female patients)

# %%
pd.crosstab(df['sex'],df['output'],normalize='columns')*100
# Out:
# output          0          1
# sex
# 0       17.391304  43.902439
# 1       82.608696  56.097561

# %%
pd.crosstab(df['sex'],df['output'],normalize='index')*100
# Out:
# output          0          1
# sex
# 0       25.000000  75.000000
# 1       55.339806  44.660194

# %%
sns.heatmap(pd.crosstab(df['sex'],df['output'],normalize='columns')*100)
# Out:
# <Axes: xlabel='output', ylabel='sex'>

# %%
counts = df.groupby(['sex', 'output']).size().unstack()

# Plotting a grouped bar chart
counts.plot(kind='bar', stacked=False)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %% [markdown]
# #### age - output

# %% [markdown]
# ##### Conclusion
# - avg age of diagonsed patients is 52
# - avg age of not diagonsed patients is 57

# %%
df[df['output'] == 1]['age'].plot(kind='kde',label='survived')
df[df['output'] == 0]['age'].plot(kind='kde',label='not survived')
plt.legend()
plt.show()

# %%
df1 = df[df['output']==0]
df1[df1['age']<40]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 212   39    1   0     118   219    0        1       140     0      1.2    1
# 227   35    1   0     120   198    0        1       130     1      1.6    1
# 239   35    1   0     126   282    0        0       156     1      0.0    2
# 259   38    1   3     120   231    0        1       182     1      3.8    1
#
#      caa  thall  output
# 212    0      3       0
# 227    0      3       0
# 239    0      3       0
# 259    0      3       0

# %%
sns.boxplot(x='output', y='age', data=df)
plt.show()

# %%
sns.violinplot(x='output', y='age', data=df)
plt.show()

# %%
sns.pointplot(x='output', y='age', data=df, ci='sd')  # sd for standard deviation
plt.show()
# Out:
# C:\Users\SVI\AppData\Local\Temp\ipykernel_13176\1481640541.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.pointplot(x='output', y='age', data=df, ci='sd')  # sd for standard deviation

# %%
df[df['output']==0]['age'].mean()
# Out:
# 56.60144927536232

# %%
df[df['output']==1]['age'].mean()
# Out:
# 52.58536585365854

# %%
df.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trtbps    0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalachh -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exng      0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slp      -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# caa       0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thall     0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="age", y="thalachh", hue="output")
plt.xlabel("Age")
plt.ylabel("Heart rate")
plt.show()
